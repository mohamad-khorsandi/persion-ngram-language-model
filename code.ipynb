# %%
from corpus import Corpus

c = Corpus("digikala_comment.csv", 1)
c.print()
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# ['باشه', 'نداشنه', 'چندانی', 'استحکام', 'میشه', 'باعث', 'که', 'هست', 'ضعیفش', 'بندهای', 'مشکلش', 'تنها', 'قشنگه', 'طراحیش', 'جاداره', 'داره', 'خرید', 'ارزش', 'قیمتش', 'به', 'نسبت', '<s>', '</s>']
# --------
# ['گرفتمش\u200c', 'که', 'میشه', 'ماهی', 'چند', '<s>', '</s>']
# --------
# ['میکنم', 'استفاده', 'ازش', 'گرافیکی', 'کارای', 'و', 'نویسی', 'برنامه', 'برای', '<s>', '</s>']
# --------
# ['عالیه', 'بگین', 'لحاظ', 'هر', 'از', 'واقعا', '<s>', '</s>']
# --------
# ['جدید', 'ستون', 'پراید', '<s>', '</s>']
# --------
# ['میشه', 'هم', 'بیشتر', 'گوشی', 'شدن', 'روشن', 'با', 'که', 'داره', 'حاشیه', 'زیاد', 'پایین', 'از', 'فقط', 'خوبه', 'چیش', 'همه', 'اقا', '<s>', '</s>']
# --------
# ...

# %%
# other preprocessing

# %%
def n_grams():
# Out:
#   Cell In[3], line 2
#
#     ^
# SyntaxError: incomplete input
